# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages

sns.set_style("whitegrid")   # optional: gives cleaner-looking charts

# %%
df = pd.read_csv("placement_predict_50k Dataset.csv")

# %%
print("First 5 rows of the dataset:")
display(df.head())          # use display() in Colab; use print(df.head()) elsewhere
# Out:
# First 5 rows of the dataset:
#    StudentID  Gender       City CollegeTier Stream Specialisation Hostel  \
# 0          1    Male  Ahmedabad       Tier2    ECE     Networking     No
# 1          2  Female     Mumbai       Tier2    ECE    DataScience    Yes
# 2          3    Male    Kolkata       Tier2     IT    DataScience    Yes
# 3          4    Male     Jaipur       Tier1     CS             AI     No
# 4          5    Male       Pune       Tier2     IT    DataScience    Yes
#
#   HistoryOfBacklogs  SGPA_Sem1  SGPA_Sem2  ...  Publications  \
# 0                No       6.02       6.54  ...             0
# 1               Yes       5.84       5.12  ...             0
# 2                No       4.91       5.29  ...             0
# 3                No       7.67       8.03  ...             0
# 4                No       8.14       8.97  ...             1
#
#    AptitudeTestScore  SoftSkillsRating  CodingTestScore  MockInterviewScore  \
# ...

# %%
df.tail()
# Out:
#        StudentID  Gender       City CollegeTier      Stream Specialisation  \
# 49995      49996    Male       Pune       Tier2  Mechanical     Networking
# 49996      49997    Male  Bangalore       Tier2          EE             AI
# 49997      49998    Male  Ahmedabad       Tier1       Civil    DataScience
# 49998      49999  Female  Bangalore       Tier3          CS    DataScience
# 49999      50000  Female      Delhi       Tier2         ECE     Networking
#
#       Hostel HistoryOfBacklogs  SGPA_Sem1  SGPA_Sem2  ...  Publications  \
# 49995     No                No       7.84       8.45  ...             1
# 49996     No                No       6.08       6.12  ...             2
# 49997    Yes               Yes       5.69       6.09  ...             0
# 49998     No                No       6.02       6.31  ...             1
# 49999     No                No       6.51       6.37  ...             0
#
#        AptitudeTestScore  SoftSkillsRating  CodingTestScore  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of        StudentID  Gender       City CollegeTier      Stream Specialisation  \
# 0              1    Male  Ahmedabad       Tier2         ECE     Networking
# 1              2  Female     Mumbai       Tier2         ECE    DataScience
# 2              3    Male    Kolkata       Tier2          IT    DataScience
# 3              4    Male     Jaipur       Tier1          CS             AI
# 4              5    Male       Pune       Tier2          IT    DataScience
# ...          ...     ...        ...         ...         ...            ...
# 49995      49996    Male       Pune       Tier2  Mechanical     Networking
# 49996      49997    Male  Bangalore       Tier2          EE             AI
# 49997      49998    Male  Ahmedabad       Tier1       Civil    DataScience
# 49998      49999  Female  Bangalore       Tier3          CS    DataScience
# 49999      50000  Female      Delhi       Tier2         ECE     Networking
#
# ...

# %%
df.isnull().sum()
# Out:
# StudentID                0
# Gender                   0
# City                     0
# CollegeTier              0
# Stream                   0
# Specialisation           0
# Hostel                   0
# HistoryOfBacklogs        0
# SGPA_Sem1                0
# SGPA_Sem2                0
# SGPA_Sem3                0
# SGPA_Sem4                0
# SGPA_Sem5                0
# SGPA_Sem6                0
# SGPA_Sem7                0
# SGPA_Sem8                0
# CGPA                     0
# AttendancePercent        0
# Internships              0
# Projects                 0
# Workshops             4488
# Certifications           0
# Publications             0
# AptitudeTestScore     4029
# SoftSkillsRating      3526
# CodingTestScore       2976
# MockInterviewScore    4957
# ExtraCurricular          0
# CGPA_Tier                0
# PlacementStatus          0
# IsAnomaly                0
# Salary Package           0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(19976)

# %%
df[df.isnull().any(axis=1)]
# Out:
#        StudentID  Gender       City CollegeTier      Stream Specialisation  \
# 0              1    Male  Ahmedabad       Tier2         ECE     Networking
# 4              5    Male       Pune       Tier2          IT    DataScience
# 5              6    Male  Ahmedabad       Tier2          EE     Networking
# 7              8    Male      Delhi       Tier2  Mechanical       Embedded
# 9             10  Female  Hyderabad       Tier2          CS    DataScience
# ...          ...     ...        ...         ...         ...            ...
# 49990      49991    Male      Delhi       Tier2          IT    DataScience
# 49992      49993    Male  Ahmedabad       Tier1          CS       Embedded
# 49995      49996    Male       Pune       Tier2  Mechanical     Networking
# 49997      49998    Male  Ahmedabad       Tier1       Civil    DataScience
# 49998      49999  Female  Bangalore       Tier3          CS    DataScience
#
# ...

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_919/3627053830.py in <cell line: 0>()
# ----> 1 df.describe()
#
# NameError: name 'df' is not defined

# %%
df.describe(include='all')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_919/2884002236.py in <cell line: 0>()
# ----> 1 df.describe(include='all')
#
# NameError: name 'df' is not defined

# %%
# Cell 1: Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

# Cell 2: Load the dataset into 'df'
df = pd.read_csv("placement_predict_50k Dataset.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_919/675484776.py in <cell line: 0>()
#       7
#       8 # Cell 2: Load the dataset into 'df'
# ----> 9 df = pd.read_csv("placement_predict_50k Dataset.csv")
#
# ...

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_919/1766884610.py in <cell line: 0>()
# ----> 1 (df.isnull().sum() / len(df)) * 100
#
# NameError: name 'df' is not defined

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_919/1766884610.py in <cell line: 0>()
# ----> 1 (df.isnull().sum() / len(df)) * 100
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the file using the exact file path in Colab session storage
df = pd.read_csv('/content/placement_predict_50k Dataset.csv')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the file using the exact file path in Colab session storage
df = pd.read_csv('/content/placement_predict_50k Dataset.csv')

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# StudentID             0.000
# Gender                0.000
# City                  0.000
# CollegeTier           0.000
# Stream                0.000
# Specialisation        0.000
# Hostel                0.000
# HistoryOfBacklogs     0.000
# SGPA_Sem1             0.000
# SGPA_Sem2             0.000
# SGPA_Sem3             0.000
# SGPA_Sem4             0.000
# SGPA_Sem5             0.000
# SGPA_Sem6             0.000
# SGPA_Sem7             0.000
# SGPA_Sem8             0.000
# CGPA                  0.000
# AttendancePercent     0.000
# Internships           0.000
# Projects              0.000
# Workshops             8.976
# Certifications        0.000
# Publications          0.000
# AptitudeTestScore     8.058
# SoftSkillsRating      7.052
# CodingTestScore       5.952
# MockInterviewScore    9.914
# ExtraCurricular       0.000
# CGPA_Tier             0.000
# PlacementStatus       0.000
# IsAnomaly             0.000
# Salary Package        0.000
# dtype: float64

# %%
df['CGPA'].mean()
# Out:
# np.float64(7.246153799999999)

# %%
df['CodingTestScore'].median()
# Out:
# 57.7

# %%
# Unique values in a single column
df['CollegeTier'].unique()
# Out:
# array(['Tier2', 'Tier1', 'Tier3'], dtype=object)

# %%
df['Salary Package'].max()

# Lowest aptitude score recorded
df['AptitudeTestScore'].min()

# Count of students who received a salary package > 10
(df['Salary Package'] > 10).sum()

# Count of students placed (PlacementStatus == 1)
(df['PlacementStatus'] == 1).sum()
# Out:
# np.int64(32856)
